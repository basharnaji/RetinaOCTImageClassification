# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/FourthBrain/Capstone Samsung OCT/sinGAN-tf')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python main.py train --image images/train/CNV-53018-1.jpeg --num_scales 8
# Out:
# Directory ./training_checkpoints already exists
# 2021-08-17 23:28:20.874713: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-17 23:28:20.883977: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-17 23:28:20.884993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-17 23:28:20.886504: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# dir_path = "./images/batch/"
#
# for f in os.listdir(dir_path):
#   file_path = dir_path + f
#   print (file_path)
#   !python main.py inference --image file_path  --dir ./training_checkpoints  --mode random_sample  --inject_scale 0

# %%
# !python main.py inference --image ./images/batch/CNV-6668596-1.jpeg  --dir ./training_checkpoints  --mode random_sample  --inject_scale 0
# Out:
# 2021-08-18 01:33:09.008548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 01:33:09.017429: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 01:33:09.018432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 01:33:09.019730: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python main.py inference --image NORMAL-220042-1.jpeg  --dir ./training_checkpoints  --mode random_sample  --inject_scale 0 --num_samples 1
# Out:
# Traceback (most recent call last):
#   File "main.py", line 97, in <module>
#     main()
#   File "main.py", line 68, in main
#     assert os.path.exists(args.image), 'Reference image not found !'
# AssertionError: Reference image not found !
