# %%
from google.colab import drive
import os
import time
import pandas as pd
import numpy as np

# %%
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/FourthBrain/Capstone Samsung OCT/')
# Out:
# Mounted at /content/drive

# %%
sinGAN_dir = "./sinGAN-tf/"
data_dir = "./Data/OCT2017/"

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/FourthBrain/Capstone Samsung OCT'

# %%
train_df = pd.read_csv(data_dir + "train_data.csv")
sample_df = train_df.sample(frac=0.1, random_state=10, axis=0)

# %%
sample_df.shape
# Out:
# (8348, 6)

# %%
os.chdir(sinGAN_dir)

# %%
# !python main.py train --image images/batch/CNV-8598714-1.jpeg --num_scales 8
# Out:
# Directory ./training_checkpoints already exists
# 2021-08-18 22:37:20.505646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 22:37:20.513304: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 22:37:20.513935: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 22:37:20.514811: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-08-18 22:37:20.515048: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 22:37:20.515654: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 22:37:20.516242: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 22:37:20.997231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 22:37:20.997930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 22:37:20.998511: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 22:37:20.999072: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-08-18 22:37:20.999124: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14684 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0
# (1, 25, 33, 3)
# (1, 28, 44, 3)
# (1, 38, 59, 3)
# (1, 50, 79, 3)
# (1, 67, 105, 3)
# (1, 90, 140, 3)
# (1, 120, 187, 3)
# (1, 161, 250, 3)
# 0
# 2021-08-18 22:37:21.577464: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8004
# 2021-08-18 22:37:34.447814: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
#  dis_loss = -1.425
#  gen_loss = 2.261
#  rec_loss = 0.034
# Time taken for scale 0 is 109.91 sec
#
# 1
#  dis_loss = -0.393
#  gen_loss = 1.122
#  rec_loss = 0.001
# Time taken for scale 1 is 122.90 sec
#
# 2
#  dis_loss = -0.118
#  gen_loss = 3.238
#  rec_loss = 0.001
# Time taken for scale 2 is 144.37 sec
#
# 3
#  dis_loss = -0.021
#  gen_loss = 3.204
#  rec_loss = 0.000
# Time taken for scale 3 is 165.47 sec
#
# 4
#  dis_loss = 0.032
#  gen_loss = -0.050
#  rec_loss = 0.001
# Time taken for scale 4 is 175.40 sec
#
# 5
#  dis_loss = -0.005
#  gen_loss = -0.107
#  rec_loss = 0.000
# Time taken for scale 5 is 196.54 sec
#
# 6
#  dis_loss = 0.008
#  gen_loss = -0.206
#  rec_loss = 0.001
# Time taken for scale 6 is 252.11 sec
#
# 7
#  dis_loss = -0.002
#  gen_loss = -0.040
#  rec_loss = 0.001
# Time taken for scale 7 is 369.30 sec

# %% [markdown]
# dir_path = "./images/batch/"
#
# for f in os.listdir(dir_path):
#   file_path = dir_path + f
#   print (file_path)
#   !python main.py inference --image file_path  --dir ./training_checkpoints  --mode random_sample  --inject_scale 0

# %%
# !python main.py inference --image images/batch/CNV-8598714-1.jpeg  --dir ./training_checkpoints  --mode random_sample  --inject_scale 0
# Out:
# images/batch/CNV-8598714-1.jpeg
# 2021-08-18 23:50:41.113871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 23:50:41.122121: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 23:50:41.122726: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 23:50:41.123550: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-08-18 23:50:41.123773: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 23:50:41.124392: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 23:50:41.124983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 23:50:41.606621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 23:50:41.607309: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 23:50:41.607899: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 23:50:41.608454: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-08-18 23:50:41.608504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14684 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0
# (1, 21, 33, 3)
# (1, 28, 44, 3)
# (1, 38, 59, 3)
# (1, 50, 79, 3)
# (1, 67, 105, 3)
# (1, 90, 140, 3)
# (1, 120, 187, 3)
# (1, 161, 250, 3)
# Directory ./results/random_sample already exists
# 2021-08-18 23:50:43.556984: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-08-18 23:50:44.187760: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8004

# %%
# !python main.py inference --image NORMAL-220042-1.jpeg  --dir ./training_checkpoints  --mode random_sample  --inject_scale 0 --num_samples 1
# Out:
# Traceback (most recent call last):
#   File "main.py", line 97, in <module>
#     main()
#   File "main.py", line 68, in main
#     assert os.path.exists(args.image), 'Reference image not found !'
# AssertionError: Reference image not found !

# %%
def infer_images (image):
  # !python main.py inference --image $image  --dir ./training_checkpoints  --mode random_sample  --inject_scale 0
  time.sleep(5)
  return

# %%
dir_path = "images/batch/"

for f in os.listdir(dir_path): 
  file_path = dir_path + f 
  print (file_path)
  infer_images (file_path)
  #assert os.path.exists(file_path), "Hello***"
  break
# Out:
# images/batch/CNV-6875371-1.jpeg
# images/batch/CNV-6875371-1.jpeg
# 2021-08-18 16:10:46.509774: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 16:10:46.517805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 16:10:46.518383: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 16:10:46.519389: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 16:10:46.519979: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 16:10:46.520510: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 16:10:47.119443: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 16:10:47.120138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 16:10:47.120720: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 16:10:47.121231: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-08-18 16:10:47.121329: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15435 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# (1, 32, 33, 3)
# (1, 43, 44, 3)
# (1, 57, 59, 3)
# (1, 76, 79, 3)
# (1, 102, 105, 3)
# (1, 136, 140, 3)
# (1, 181, 187, 3)
# (1, 242, 250, 3)
# Directory ./results/random_sample already exists
# 2021-08-18 16:10:49.461908: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-08-18 16:10:49.976689: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8004

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/FourthBrain/Capstone Samsung OCT/sinGAN-tf'
